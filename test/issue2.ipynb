# %% [markdown]
# Fix: https://github.com/MuGdxy/SymEigen/issues/2

# %%
import sys
sys.path.append('..')
from SymEigen import *
Gen = EigenFunctionGenerator()
Gen.DisableCommonSubExpression()
a = Eigen.Scalar('a')
b = Eigen.Scalar('b')
Closure = Gen.Closure(a, b)

# %%
Expression = (a+b)*(a+b)
Expression
# Out:
# Matrix([[(a + b)**2]])

# %%
print(Closure('Expression', Expression, 'Expression'))
# Out:
# template <typename T>
# void Expression(T& Expression, const T& a, const T& b)
# {
# /*****************************************************************************************************************************
# Function generated by SymEigen.py
# Author: MuGdxy
# GitHub: https://github.com/MuGdxy/SymEigen
# E-Mail: lxy819469559@gmail.com
# ******************************************************************************************************************************
# LaTeX expression:
# //tex:$$Expression = \left[\begin{matrix}\left(a + b\right)^{2}\end{matrix}\right]$$
#
# Symbol Name Mapping:
# a:
#     -> {}
#     -> Matrix([[a]])
# b:
#     -> {}
#     -> Matrix([[b]])
# *****************************************************************************************************************************/
# Expression = (a + b) * (a + b);
# }
